# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !git clone https://github.com/schraj/simple-unet-2.git
# Out:
# Cloning into 'simple-unet-2'...
# remote: Enumerating objects: 160, done.
# remote: Counting objects: 100% (160/160), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 160 (delta 99), reused 109 (delta 48), pack-reused 0
# Receiving objects: 100% (160/160), 30.27 KiB | 4.32 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
# Change directory to the local repository's directory
# %cd /kaggle/working/simple-unet-2

# Pull the latest changes
# !git pull origin main
# Out:
# /kaggle/working/simple-unet-2
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 12 (delta 10), reused 8 (delta 6), pack-reused 0
# Unpacking objects: 100% (12/12), 862 bytes | 287.00 KiB/s, done.
# From https://github.com/schraj/simple-unet-2
#  * branch            main       -> FETCH_HEAD
#    9b16448..834876b  main       -> origin/main
# Updating 9b16448..834876b
# Fast-forward
#  src/lung/prepare_data.py |  2 +-
#  src/model_api/trainer.py | 11 ++---------
#  2 files changed, 3 insertions(+), 10 deletions(-)

# %%
import sys
sys.path.append('/kaggle/working/simple-unet-2/src')

# %%
import os
os.mkdir('/kaggle/working/simple-unet-2/segmentation')
os.mkdir('/kaggle/working/simple-unet-2/saved_model')
os.mkdir('/kaggle/working/simple-unet-2/saved_images')

# %%
from src.model_api.processor import Processor

processor = Processor()
processor.run_training(update_data=True)
# Out:
# Input Mont Files:  138
# montgomery data prepared
# Input Shen Files:  566
# shenzhen data prepared
# 660 200 660
# Got 8857420/34603008 with acc 25.60
# TM Dice score: 0.40418046712875366
# Epoch  0
# 100%|██████████| 528/528 [01:03<00:00,  8.28it/s, loss=-1.58]
# Got 30447440/34603008 with acc 87.99
# TM Dice score: 0.7639713883399963
# Model saved
# Epoch  1
# 100%|██████████| 528/528 [01:03<00:00,  8.28it/s, loss=-1.36]
# Got 30403489/34603008 with acc 87.86
# TM Dice score: 0.7741206288337708
# Epoch  2
# 100%|██████████| 528/528 [01:03<00:00,  8.28it/s, loss=-3.65]
# Got 29641817/34603008 with acc 85.66
# TM Dice score: 0.775850772857666
# Epoch  3
# 100%|██████████| 528/528 [01:03<00:00,  8.28it/s, loss=-7.88]
# Got 31688384/34603008 with acc 91.58
# TM Dice score: 0.8390859365463257
# Epoch  4
# 100%|██████████| 528/528 [01:03<00:00,  8.28it/s, loss=-12.9]
# Got 29859156/34603008 with acc 86.29
# TM Dice score: 0.7927285432815552
# Epoch  5
# ...

# %%
from src.visualization.visualizer import Visualizer
Visualizer.show_sample_montgomery_image()

# %%
from src.visualization.visualizer import Visualizer
Visualizer.show_sample_shenszhen_image()

# %%
# Change directory to the local repository's directory
# %cd /kaggle/working/simple-unet-2

# Pull the latest changes
# !git pull origin main
# Out:
# /kaggle/working/simple-unet-2
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 15 (delta 12), reused 11 (delta 8), pack-reused 0
# Unpacking objects: 100% (15/15), 1.05 KiB | 268.00 KiB/s, done.
# From https://github.com/schraj/simple-unet-2
#  * branch            main       -> FETCH_HEAD
#    020f4a5..e4a19dd  main       -> origin/main
# Updating 020f4a5..e4a19dd
# Fast-forward
#  src/model_api/trainer.py        |  2 +-
#  src/visualization/visualizer.py | 13 ++++++++-----
#  2 files changed, 9 insertions(+), 6 deletions(-)

# %%
from src.model_api.processor import Processor
processor = Processor()
# processor.run_training(update_data=True)
preds_array = processor.run_test(True)
# Out:
# Got 21629556/26214400 with acc 82.51
# TM Dice score: 0.6842565536499023
